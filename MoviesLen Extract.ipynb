# %%
import pandas as pd

# %%
file_dir = 'C://Users/15304/Desktop/Class/Movies-ETL'

# %%
f'{file_dir}movies_metadata.csv'
# Out:
# 'C://Users/15304/Desktop/Class/Movies-ETLmovies_metadata.csv'

# %%
f'{file_dir}ratings.csv'
# Out:
# 'C://Users/15304/Desktop/Class/Movies-ETLratings.csv'

# %%
movies_metadata = pd.read_csv('movies_metadata.csv', low_memory = False)

# %%
ratings = pd.read_csv('ratings.csv')

# %%
movies_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
movies_metadata.tail()
# Out:
#        adult belongs_to_collection budget  \
# 45461  False                   NaN      0
# 45462  False                   NaN      0
# 45463  False                   NaN      0
# 45464  False                   NaN      0
# 45465  False                   NaN      0
#
#                                                   genres  \
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# ...

# %%
ratings.tail()
# Out:
#           userId  movieId  rating   timestamp
# 26024284  270896    58559     5.0  1257031564
# 26024285  270896    60069     5.0  1257032032
# 26024286  270896    63082     4.5  1257031764
# 26024287  270896    64957     4.5  1257033990
# 26024288  270896    71878     2.0  1257031858

# %%
ratings.sample(10)
# Out:
#           userId  movieId  rating   timestamp
# 22171461  230140     4014     3.5  1330454586
# 2176436    22605      480     4.0   879496441
# 3811219    39742      146     3.0  1436797945
# 10738171  110868     2844     3.0  1056493128
# 9699186   100090    48322     4.0  1168878342
# 12706299  131890     8531     0.5  1089207856
# 24667295  256396     2469     3.0  1022339050
# 22354173  231990     1263     4.0  1093490549
# 11311066  117343     1747     3.5  1335180491
# 24774466  257552     2628     3.0  1259711365

# %%
movies_metadata.sample(5)
# Out:
#        adult belongs_to_collection    budget  \
# 31901  False                   NaN         0
# 40040  False                   NaN    980000
# 40015  False                   NaN  60000000
# 22672  False                   NaN  18000000
# 43435  False                   NaN         0
#
#                                                   genres  \
# 31901                     [{'id': 27, 'name': 'Horror'}]
# 40040  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...
# 40015  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 22672                      [{'id': 18, 'name': 'Drama'}]
# 43435                   [{'id': 10402, 'name': 'Music'}]
#
#                         homepage      id    imdb_id original_language  \
# 31901  http://www.exte-movie.jp/   21784  tt0904049                cs
# 40040                        NaN  298721  tt2818654                th
# 40015    http://kubothemovie.com  313297  tt4302938                en
# ...
